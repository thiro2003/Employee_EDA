# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("C:/Users/sonu_/OneDrive/Desktop/Data Analysis Projects/employee_data/employee_data.csv")
data.head()
# Out:
#    ID Gender  Experience (Years)               Position  Salary
# 0   1      F                   4        DevOps Engineer  109976
# 1   2      M                   6        DevOps Engineer  120088
# 2   3      M                  17          Web Developer  181301
# 3   4      M                   7  Systems Administrator   77530
# 4   5      F                  13  Systems Administrator  152397

# %%
# getting number of rows and columns
data.shape
# Out:
# (400, 5)

# %%
# getting employee based on gender
data["Gender"].value_counts()
# Out:
# Gender
# M    202
# F    198
# Name: count, dtype: int64

# %%
x=sns.countplot(x="Gender",data=data)
x.bar_label(x.containers[0])
plt.show()

# %%
# following data has more male employers than women

# %%
data.head()
# Out:
#    ID Gender  Experience (Years)               Position  Salary
# 0   1      F                   4        DevOps Engineer  109976
# 1   2      M                   6        DevOps Engineer  120088
# 2   3      M                  17          Web Developer  181301
# 3   4      M                   7  Systems Administrator   77530
# 4   5      F                  13  Systems Administrator  152397

# %%
# getting total number and types of position in a company
data["Position"].value_counts()
# Out:
# Position
# Web Developer                   43
# IT Manager                      40
# IT Security Analyst             39
# Database Administrator (DBA)    38
# Systems Administrator           38
# DevOps Engineer                 37
# Systems Analyst                 37
# Software Engineer               36
# Network Administrator           31
# IT Support Specialist           31
# Cloud Solutions Architect       30
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,10))
x=sns.countplot(x="Position",data=data)
x.bar_label(x.containers[0])
plt.show()

# %%
data["Position"].max()
# Out:
# 'Web Developer'

# %%
# maximum number of position is WEB DEVELOPER

# %%
data.head()
# Out:
#    ID Gender  Experience (Years)               Position  Salary
# 0   1      F                   4        DevOps Engineer  109976
# 1   2      M                   6        DevOps Engineer  120088
# 2   3      M                  17          Web Developer  181301
# 3   4      M                   7  Systems Administrator   77530
# 4   5      F                  13  Systems Administrator  152397

# %%
# return maximum salary
data["Salary"].max()
# Out:
# np.int64(269950)

# %%
# maximum salary is 269950

# %%
"""CONCLUSION"""
 # 1> following data has more male employers than women
 # 2> maximum number of position is WEB DEVELOPER
